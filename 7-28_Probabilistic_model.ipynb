# %%
# read a csv file and perform Probabilistic modeling

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB


df_br= pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data")

df_br.head()
# Out:
#    1000025  5   1  1.1  1.2  2 1.3  3  1.4  1.5  2.1
# 0  1002945  5   4    4    5  7  10  3    2    1    2
# 1  1015425  3   1    1    1  2   2  3    1    1    2
# 2  1016277  6   8    8    1  3   4  3    7    1    2
# 3  1017023  4   1    1    3  2   1  3    1    1    2
# 4  1017122  8  10   10    8  7  10  9    7    1    4

# %%
# naming each columns of the CSV file
df_br=df_br.rename(columns={'1000025':'PatientIdNumber', '5':'ClumpThickness', '1':'UniformityOfCellSize','1.1':'UniformityOfCellShape','1.2':'MarginalAdhesion','2': 'SingleEpithelialCellSize','1.3':'BareNuclei','3':'BlandChromatin','1.4':'NormalNucleoli','1.5':'Mitoses','2.1':'Class'})

df_br.head(10)
# Out:
#    PatientIdNumber  ClumpThickness  UniformityOfCellSize  \
# 0          1002945               5                     4
# 1          1015425               3                     1
# 2          1016277               6                     8
# 3          1017023               4                     1
# 4          1017122               8                    10
# 5          1018099               1                     1
# 6          1018561               2                     1
# 7          1033078               2                     1
# 8          1033078               4                     2
# 9          1035283               1                     1
#
#    UniformityOfCellShape  MarginalAdhesion  SingleEpithelialCellSize  \
# 0                      4                 5                         7
# 1                      1                 1                         2
# 2                      8                 1                         3
# ...

# %%
# Perform Logistic regression, Naive Bayes or KNN on the BREAST Cancer data file
#df_br.head(10)

# ignore the first colum, i.e. Patient number
df_br.columns

df_br
# Out:
#      PatientIdNumber  ClumpThickness  UniformityOfCellSize  \
# 0            1002945               5                     4
# 1            1015425               3                     1
# 2            1016277               6                     8
# 3            1017023               4                     1
# 4            1017122               8                    10
# ..               ...             ...                   ...
# 693           776715               3                     1
# 694           841769               2                     1
# 695           888820               5                    10
# 696           897471               4                     8
# 697           897471               4                     8
#
#      UniformityOfCellShape  MarginalAdhesion  SingleEpithelialCellSize  \
# 0                        4                 5                         7
# 1                        1                 1                         2
# ...

# %%
# counting the total columns
columns=['ClumpThickness','UniformityOfCellSize','UniformityOfCellShape','MarginalAdhesion', 'SingleEpithelialCellSize',
       'BareNuclei', 'BlandChromatin', 'NormalNucleoli', 'Mitoses', 'Class']

# ignore the first column, which is PatientIdNumber


# convert column (k) to 1 and 0 using single column as X and "class" as Y

new_val= pd.get_dummies(df_br["Class"])

df_br
#df_br= df_br.append(new_val)
# Out:
#      PatientIdNumber  ClumpThickness  UniformityOfCellSize  \
# 0            1002945               5                     4
# 1            1015425               3                     1
# 2            1016277               6                     8
# 3            1017023               4                     1
# 4            1017122               8                    10
# ..               ...             ...                   ...
# 693           776715               3                     1
# 694           841769               2                     1
# 695           888820               5                    10
# 696           897471               4                     8
# 697           897471               4                     8
#
#      UniformityOfCellShape  MarginalAdhesion  SingleEpithelialCellSize  \
# 0                        4                 5                         7
# 1                        1                 1                         2
# ...

# %%
# add the new dummies columns on the original DF
df_br= pd.concat([df_br, new_val], axis="columns")


#df_br.head(10)
# NOW drop the old columns
df_br=df_br.drop(['PatientIdNumber'], axis=1)
df_br.head(10)
# Out:
#    ClumpThickness  UniformityOfCellSize  UniformityOfCellShape  \
# 0               5                     4                      4
# 1               3                     1                      1
# 2               6                     8                      8
# 3               4                     1                      1
# 4               8                    10                     10
# 5               1                     1                      1
# 6               2                     1                      2
# 7               2                     1                      1
# 8               4                     2                      1
# 9               1                     1                      1
#
#    MarginalAdhesion  SingleEpithelialCellSize BareNuclei  BlandChromatin  \
# 0                 5                         7         10               3
# 1                 1                         2          2               3
# ...

# %%
df_br=df_br.drop(['Class'], axis=1)

# %%
# rename with X and y
df_br= df_br.rename(columns={'2':'X', '4':'Y'})
df_br.head(10)
# Out:
#    ClumpThickness  UniformityOfCellSize  UniformityOfCellShape  \
# 0               5                     4                      4
# 1               3                     1                      1
# 2               6                     8                      8
# 3               4                     1                      1
# 4               8                    10                     10
# 5               1                     1                      1
# 6               2                     1                      2
# 7               2                     1                      1
# 8               4                     2                      1
# 9               1                     1                      1
#
#    MarginalAdhesion  SingleEpithelialCellSize BareNuclei  BlandChromatin  \
# 0                 5                         7         10               3
# 1                 1                         2          2               3
# ...

# %%
df_br.head(10)
# Out:
#    ClumpThickness  UniformityOfCellSize  UniformityOfCellShape  \
# 0               5                     4                      4
# 1               3                     1                      1
# 2               6                     8                      8
# 3               4                     1                      1
# 4               8                    10                     10
# 5               1                     1                      1
# 6               2                     1                      2
# 7               2                     1                      1
# 8               4                     2                      1
# 9               1                     1                      1
#
#    MarginalAdhesion  SingleEpithelialCellSize BareNuclei  BlandChromatin  \
# 0                 5                         7         10               3
# 1                 1                         2          2               3
# ...

# %%
df_br=np.array(df_br)

plt.scatter(np.array(df_br['MarginalAdhesion']))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-08eb67eff984> in <module>
#       1 df_br=np.array(df_br)
#       2
# ----> 3 plt.scatter(np.array(df_br['MarginalAdhesion']))
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
