# %%
# polynomila REgression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#OBJECTIVE:
#1. Drop most recent 4 days because the data is not reported yet
#2. REverse order of data so it si in chronological order
#3. look at new deaths as a function of date

df_covid=pd.read_csv("COVID19_line_list_data.csv")
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
# reversing the order
np.array(df_covid["date_dt"])[::-1]


#ignoring the first 9 and last 4 deaths, np.array(df_covid[9:-4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ed60a02e6593> in <module>
#       1 # reversing the order
# ----> 2 np.array(data["date_dt"])[::-1]
#
# NameError: name 'data' is not defined

# %%
## scatter polot by creating x and y values
# plt.scatter(x, yvals, marker)
# plot.grid()
# plt.show()

# TO Get the polynomial values
# a,b = 


# SPLITTING THE data sets by 75% for TESTING and 25% for TRAINING

# %%
# xtrain, xtest,ytrain,ytest = tain_test_split(xval, yval) # SPLITTIN data sets into TEST and TRAINING data sets
# fit= np.polyfit(xtrain, ytrain, 1) # returns POLYNOMIAL coefficients
# ypredicted= np.polyval(fit, xtest) # pass in coefficents and sequence of xvals, output is sequence of yvals
# mean_squared_error(ytest, ypredicted)# MSE, sum of squared errors
